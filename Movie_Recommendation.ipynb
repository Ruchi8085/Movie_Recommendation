# %% [markdown]
# # **Movie_Recommendation**

# %% [markdown]
# **Import Library**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Import Dataset**

# %%
df = pd.read_csv('/content/Movies Recommendation.csv')
df.head()
# Out:
#    Movie_ID      Movie_Title                       Movie_Genre Movie_Language  \
# 0         1       Four Rooms                      Crime Comedy             en
# 1         2        Star Wars  Adventure Action Science Fiction             en
# 2         3     Finding Nemo                  Animation Family             en
# 3         4     Forrest Gump              Comedy Drama Romance             en
# 4         5  American Beauty                             Drama             en
#
#    Movie_Budget  Movie_Popularity Movie_Release_Date  Movie_Revenue  \
# 0       4000000         22.876230         09-12-1995        4300000
# 1      11000000        126.393695         25-05-1977      775398007
# 2      94000000         85.688789         30-05-2003      940335536
# 3      55000000        138.133331         06-07-1994      677945399
# 4      15000000         80.878605         15-09-1999      356296601
#
#    Movie_Runtime  Movie_Vote  ...  \
# 0             98         6.5  ...
# 1            121         8.1  ...
# 2            100         7.6  ...
# 3            142         8.2  ...
# 4            122         7.9  ...
#
#                                       Movie_Homepage  \
# 0                                                NaN
# 1  http://www.starwars.com/films/star-wars-episod...
# 2              http://movies.disney.com/finding-nemo
# 3                                                NaN
# 4                      http://www.dreamworks.com/ab/
#
#                                       Movie_Keywords  \
# 0          hotel new year's eve witch bet hotel room
# 1        android galaxy hermit death star lightsaber
# 2  father son relationship harbor underwater fish...
# 3  vietnam veteran hippie mentally disabled runni...
# 4  male nudity female nudity adultery midlife cri...
#
#                                       Movie_Overview  \
# 0  It's Ted the Bellhop's first night on the job....
# 1  Princess Leia is captured and held hostage by ...
# 2  Nemo, an adventurous young clownfish, is unexp...
# 3  A man with a low IQ has accomplished great thi...
# 4  Lester Burnham, a depressed suburban father in...
#
#                               Movie_Production_House  \
# 0  [{"name": "Miramax Films", "id": 14}, {"name":...
# 1  [{"name": "Lucasfilm", "id": 1}, {"name": "Twe...
# 2     [{"name": "Pixar Animation Studios", "id": 3}]
# 3          [{"name": "Paramount Pictures", "id": 4}]
# 4  [{"name": "DreamWorks SKG", "id": 27}, {"name"...
#
#                             Movie_Production_Country  \
# 0  [{"iso_3166_1": "US", "name": "United States o...
# 1  [{"iso_3166_1": "US", "name": "United States o...
# 2  [{"iso_3166_1": "US", "name": "United States o...
# 3  [{"iso_3166_1": "US", "name": "United States o...
# 4  [{"iso_3166_1": "US", "name": "United States o...
#
#                       Movie_Spoken_Language  \
# 0  [{"iso_639_1": "en", "name": "English"}]
# 1  [{"iso_639_1": "en", "name": "English"}]
# 2  [{"iso_639_1": "en", "name": "English"}]
# 3  [{"iso_639_1": "en", "name": "English"}]
# 4  [{"iso_639_1": "en", "name": "English"}]
#
#                                        Movie_Tagline  \
# 0  Twelve outrageous guests. Four scandalous requ...
# 1       A long time ago in a galaxy far, far away...
# 2  There are 3.7 trillion fish in the ocean, they...
# 3  The world will never be the same, once you've ...
# 4                                       Look closer.
#
#                                           Movie_Cast  \
# 0  Tim Roth Antonio Banderas Jennifer Beals Madon...
# 1  Mark Hamill Harrison Ford Carrie Fisher Peter ...
# 2  Albert Brooks Ellen DeGeneres Alexander Gould ...
# 3  Tom Hanks Robin Wright Gary Sinise Mykelti Wil...
# 4  Kevin Spacey Annette Bening Thora Birch Wes Be...
#
#                                           Movie_Crew   Movie_Director
# 0  [{'name': 'Allison Anders', 'gender': 1, 'depa...   Allison Anders
# 1  [{'name': 'George Lucas', 'gender': 2, 'depart...     George Lucas
# 2  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...   Andrew Stanton
# 3  [{'name': 'Alan Silvestri', 'gender': 2, 'depa...  Robert Zemeckis
# 4  [{'name': 'Thomas Newman', 'gender': 2, 'depar...       Sam Mendes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Movie_ID                  425 non-null    int64
#  1   Movie_Title               425 non-null    object
#  2   Movie_Genre               425 non-null    object
#  3   Movie_Language            425 non-null    object
#  4   Movie_Budget              425 non-null    int64
#  5   Movie_Popularity          425 non-null    float64
#  6   Movie_Release_Date        425 non-null    object
#  7   Movie_Revenue             425 non-null    int64
#  8   Movie_Runtime             425 non-null    int64
#  9   Movie_Vote                425 non-null    float64
#  10  Movie_Vote_Count          425 non-null    int64
#  11  Movie_Homepage            179 non-null    object
#  12  Movie_Keywords            424 non-null    object
#  13  Movie_Overview            425 non-null    object
#  14  Movie_Production_House    425 non-null    object
#  15  Movie_Production_Country  425 non-null    object
#  16  Movie_Spoken_Language     425 non-null    object
#  17  Movie_Tagline             403 non-null    object
#  18  Movie_Cast                425 non-null    object
#  19  Movie_Crew                424 non-null    object
#  20  Movie_Director            422 non-null    object
# dtypes: float64(2), int64(5), object(14)
# memory usage: 69.9+ KB

# %%
df.shape
# Out:
# (425, 21)

# %%
df.columns
# Out:
# Index(['Movie_ID', 'Movie_Title', 'Movie_Genre', 'Movie_Language',
#        'Movie_Budget', 'Movie_Popularity', 'Movie_Release_Date',
#        'Movie_Revenue', 'Movie_Runtime', 'Movie_Vote', 'Movie_Vote_Count',
#        'Movie_Homepage', 'Movie_Keywords', 'Movie_Overview',
#        'Movie_Production_House', 'Movie_Production_Country',
#        'Movie_Spoken_Language', 'Movie_Tagline', 'Movie_Cast', 'Movie_Crew',
#        'Movie_Director'],
#       dtype='object')

# %% [markdown]
# **Get Feature Selection**

# %%
df_features = df[['Movie_Genre','Movie_Keywords','Movie_Tagline','Movie_Cast','Movie_Director']].fillna('')

# %%
df_features.shape
# Out:
# (425, 5)

# %%
df_features
# Out:
#                            Movie_Genre  \
# 0                         Crime Comedy
# 1     Adventure Action Science Fiction
# 2                     Animation Family
# 3                 Comedy Drama Romance
# 4                                Drama
# ..                                 ...
# 420                    Horror Thriller
# 421  Animation Family Comedy Adventure
# 422                             Comedy
# 423                   Family Animation
# 424          Adventure Action Thriller
#
#                                         Movie_Keywords  \
# 0            hotel new year's eve witch bet hotel room
# 1          android galaxy hermit death star lightsaber
# 2    father son relationship harbor underwater fish...
# 3    vietnam veteran hippie mentally disabled runni...
# 4    male nudity female nudity adultery midlife cri...
# ..                                                 ...
# 420     female nudity nudity mask babysitter halloween
# 421      mammoth sloth ice age barrier ice ice melting
# 422  crime fighter cook drug dealer dying and death...
# 423            lion hippopotamus giraffe penguin zebra
# 424             paris london england spy cia terrorist
#
#                                          Movie_Tagline  \
# 0    Twelve outrageous guests. Four scandalous requ...
# 1         A long time ago in a galaxy far, far away...
# 2    There are 3.7 trillion fish in the ocean, they...
# 3    The world will never be the same, once you've ...
# 4                                         Look closer.
# ..                                                 ...
# 420                             The Night He Came Home
# 421                       The Ice age is melting away.
# 422  Go ahead, you tell him you didn't do your home...
# 423                         Someone's got a zoo loose.
# 424                             Expect the Impossible.
#
#                                             Movie_Cast   Movie_Director
# 0    Tim Roth Antonio Banderas Jennifer Beals Madon...   Allison Anders
# 1    Mark Hamill Harrison Ford Carrie Fisher Peter ...     George Lucas
# 2    Albert Brooks Ellen DeGeneres Alexander Gould ...   Andrew Stanton
# 3    Tom Hanks Robin Wright Gary Sinise Mykelti Wil...  Robert Zemeckis
# 4    Kevin Spacey Annette Bening Thora Birch Wes Be...       Sam Mendes
# ..                                                 ...              ...
# 420  Donald Pleasence Jamie Lee Curtis P.J. Soles N...   John Carpenter
# 421  Ray Romano John Leguizamo Denis Leary Queen La...  Carlos Saldanha
# 422  Arnold Schwarzenegger Penelope Ann Miller Pame...     Ivan Reitman
# 423  Ben Stiller Chris Rock David Schwimmer Jada Pi...     Eric Darnell
# 424  Tom Cruise Jon Voight Emmanuelle B\u00e9art He...
#
# [425 rows x 5 columns]

# %%
x = df_features['Movie_Genre'] + ' ' + df_features['Movie_Keywords'] + ' ' + df_features['Movie_Tagline'] + ' ' + df_features['Movie_Cast']+ ' ' + df_features['Movie_Director']

# %%
x.shape
# Out:
# (425,)

# %% [markdown]
# **Get Features Text Conversion to Tokens**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
x = tfidf.fit_transform(x)

# %%
x.shape
# Out:
# (425, 4240)

# %%
print(x)
# Out:
#   (0, 127)	0.1672090120132036
#   (0, 103)	0.1672090120132036
#   (0, 3764)	0.1672090120132036
#   (0, 2380)	0.1672090120132036
#   (0, 2332)	0.1672090120132036
#   (0, 301)	0.1565512056483183
#   (0, 1915)	0.1342796553994632
#   (0, 266)	0.14312395759306187
#   (0, 164)	0.14312395759306187
#   (0, 3185)	0.14898937169139476
#   (0, 3743)	0.10540220871276905
#   (0, 2215)	0.08846503662763536
#   (0, 2727)	0.060935853918451556
#   (0, 4115)	0.1672090120132036
#   (0, 1345)	0.09602687058455887
#   (0, 4100)	0.11606001507765436
#   (0, 1935)	0.14312395759306187
#   (0, 3703)	0.09874313029471359
#   (0, 2748)	0.08106800186093915
#   (0, 942)	0.13076973136958592
#   (0, 1317)	0.11424651090636771
#   (0, 1725)	0.20602196104447124
#   (0, 1827)	0.14530455043423893
#   (0, 333)	0.1672090120132036
#   (0, 2257)	0.1565512056483183
#   :	:
#   (423, 3442)	0.16000679847063223
#   (423, 697)	0.1484086444322044
#   (423, 936)	0.12272815875142952
#   (423, 1243)	0.10991995927170993
#   (423, 148)	0.1446535633789776
#   (424, 894)	0.2930287394494673
#   (424, 3877)	0.2930287394494673
#   (424, 1825)	0.2930287394494673
#   (424, 1218)	0.2743512559406703
#   (424, 4003)	0.2743512559406703
#   (424, 1164)	0.2743512559406703
#   (424, 711)	0.2508204095793724
#   (424, 1949)	0.2508204095793724
#   (424, 1692)	0.24242188698835118
#   (424, 3508)	0.21889104062705336
#   (424, 2256)	0.16984584084500393
#   (424, 3691)	0.2610993704971482
#   (424, 2819)	0.2145006398849977
#   (424, 871)	0.2145006398849977
#   (424, 1174)	0.16677374654522595
#   (424, 3734)	0.1018138165464154
#   (424, 3763)	0.16531126364019097
#   (424, 33)	0.10404317136820909
#   (424, 52)	0.10598710294036577
#   (424, 3703)	0.08652217560280069

# %% [markdown]
# **Get Similarity Score Using Cosine Similarity**

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
Similarity_Score = cosine_similarity(x)

# %%
Similarity_Score
# Out:
# array([[1.        , 0.01333813, 0.03900162, ..., 0.01804607, 0.        ,
#         0.00854347],
#        [0.01333813, 1.        , 0.00791895, ..., 0.01833343, 0.        ,
#         0.01590329],
#        [0.03900162, 0.00791895, 1.        , ..., 0.        , 0.02890563,
#         0.00507233],
#        ...,
#        [0.01804607, 0.01833343, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.02890563, ..., 0.        , 1.        ,
#         0.        ],
#        [0.00854347, 0.01590329, 0.00507233, ..., 0.        , 0.        ,
#         1.        ]])

# %%
Similarity_Score.shape
# Out:
# (425, 425)

# %% [markdown]
# **Get Movie Name as Input form User & Validate for Closest Spelling**

# %%
Favourite_Movie_Name = input(' Enter your favourite movie name :')
# Out:
#  Enter your favourite movie name :a man

# %%
All_Movies_Title_List = df['Movie_Title'].tolist()

# %%
import difflib

# %%
Movie_Recommendation = difflib.get_close_matches(Favourite_Movie_Name, All_Movies_Title_List)

# %%
print(Movie_Recommendation)
# Out:
# ['Batman', 'Rain Man', 'Catwoman']

# %%
Close_Match = Movie_Recommendation[0]

# %%
print(Close_Match)
# Out:
# Batman

# %%
Index_of_Close_Match_Movie = df[df.Movie_Title == Close_Match]['Movie_ID'].values[0]

# %%
print(Index_of_Close_Match_Movie)
# Out:
# 123

# %%
Recommendation_Score = list(enumerate(Similarity_Score[Index_of_Close_Match_Movie]))
print(Recommendation_Score)
# Out:
# [(0, 0.01986386154878452), (1, 0.006580373039220623), (2, 0.004276756339350732), (3, 0.03933168806824346), (4, 0.004288983247820145), (5, 0.022327563010149494), (6, 0.07110613636705647), (7, 0.014914624647425167), (8, 0.004810479678325028), (9, 0.011656289812898393), (10, 0.11656178723218141), (11, 0.009558022241540612), (12, 0.01053146996278628), (13, 0.0), (14, 0.004540389495911348), (15, 0.0038440257108925046), (16, 0.023630122196118618), (17, 0.007940379939752185), (18, 0.09421290187274517), (19, 0.029463364462237365), (20, 0.020296931128523654), (21, 0.023473782660669896), (22, 0.0), (23, 0.004316498740427927), (24, 0.0027342210307742527), (25, 0.028238469922305894), (26, 0.00417977068971341), (27, 0.0), (28, 0.005068433645934761), (29, 0.009130388027555598), (30, 0.06835143662038692), (31, 0.004071673632256766), (32, 0.010287314787682775), (33, 0.008513957243919824), (34, 0.020453290187928908), (35, 0.07116616707638156), (36, 0.006785599098855267), (37, 0.02141285027487828), (38, 0.03440754263629347), (39, 0.03209221429824051), (40, 0.028491924443851388), (41, 0.012566251293506546), (42, 0.017946032471372535), (43, 0.02020619686798185), (44, 0.00987024986731968), (45, 0.04204481105518902), (46, 0.006898571784702298), (47, 0.016439772542459825), (48, 0.038033972510220594), (49, 0.0), (50, 0.016942933685997464), (51, 0.02304025340956574), (52, 0.02091517238341891), (53, 0.0), (54, 0.00767788106309689), (55, 0.00781324816483298), (56, 0.01792224933561488), (57, 0.013457224377964727), (58, 0.00461328107363558), (59, 0.007240669048074394), (60, 0.007937931259173534), (61, 0.003922999455930729), (62, 0.004702216914961018), (63, 0.0742888699096764), (64, 0.004709349999921729), (65, 0.005472824940301478), (66, 0.0042869650007310136), (67, 0.021654312465984184), (68, 0.4217605856889931), (69, 0.008780126163164382), (70, 0.01903601136539876), (71, 0.019803107436079152), (72, 0.02271575479660122), (73, 0.03583543397623274), (74, 0.014917771120409554), (75, 0.018166782478616993), (76, 0.02649131699355328), (77, 0.018892368909583724), (78, 0.011591772386810384), (79, 0.009614324639040859), (80, 0.012443518260490203), (81, 0.0316863776504859), (82, 0.023637698750867082), (83, 0.023261957177369095), (84, 0.011782212772948313), (85, 0.021528437380150457), (86, 0.03249176633207422), (87, 0.03799104805339161), (88, 0.02350797258257628), (89, 0.018256868029913522), (90, 0.02305333193950527), (91, 0.03843782487651397), (92, 0.010060427511450715), (93, 0.024139264603777303), (94, 0.026557936573352044), (95, 0.024696297784468677), (96, 0.044594258161412006), (97, 0.008463748641264819), (98, 0.004157245564265558), (99, 0.016186342648137366), (100, 0.0), (101, 0.019358916797967057), (102, 0.031022947848835858), (103, 0.004030930299105648), (104, 0.03171409892480332), (105, 0.045374227826071076), (106, 0.020493743723057838), (107, 0.004780558212397141), (108, 0.029436265390122635), (109, 0.04118155474311707), (110, 0.005019086118750031), (111, 0.020733643974259138), (112, 0.026400361389832726), (113, 0.0035167561433228725), (114, 0.004069489010485946), (115, 0.004288562262751465), (116, 0.0040177544547021085), (117, 0.0), (118, 0.007612960097986227), (119, 0.019534811201939457), (120, 0.023607803543771993), (121, 0.003946082569729814), (122, 0.1850850784686242), (123, 0.9999999999999999), (124, 0.028036084227218268), (125, 0.025616711147621735), (126, 0.01981749768849594), (127, 0.0042873888488011635), (128, 0.02500340306039696), (129, 0.002991813157929864), (130, 0.02086426589708116), (131, 0.02929375885381416), (132, 0.01828311931495863), (133, 0.0), (134, 0.0), (135, 0.017753513454401057), (136, 0.003936723758062158), (137, 0.022520067969325527), (138, 0.02126964459640922), (139, 0.028356304796176297), (140, 0.004357013171752701), (141, 0.0), (142, 0.035018000555757885), (143, 0.0972658781395518), (144, 0.12662250423476124), (145, 0.10301409184878946), (146, 0.0), (147, 0.019525555627356268), (148, 0.02604361287267278), (149, 0.01934855438788 ...

# %%
Sorted_Similar_Movies = sorted(Recommendation_Score, key=lambda x: x[1], reverse=True)

print('Top 30 Movies Suggested for You : \n')

i = 1
for movie in Sorted_Similar_Movies:
  index = movie[0]
  title_from_index = df[df.index==index]['Movie_Title'].values[0]
  if (i<31):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Top 30 Movies Suggested for You :
#
# 1 . Batman Begins
# 2 . The Dark Knight
# 3 . Batman Returns
# 4 . Batman
# 5 . Batman & Robin
# 6 . The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# 7 . True Romance
# 8 . Kill Bill: Vol. 1
# 9 . The Man with the Golden Gun
# 10 . Shaft
# 11 . GoldenEye
# 12 . Insomnia
# 13 . Terminator Salvation
# 14 . Batman Forever
# 15 . Catwoman
# 16 . A History of Violence
# 17 . Schindler's List
# 18 . JFK
# 19 . The Matrix Reloaded
# 20 . Jaws: The Revenge
# 21 . Mr. & Mrs. Smith
# 22 . Things to Do in Denver When You're Dead
# 23 . Crouching Tiger, Hidden Dragon
# 24 . Raiders of the Lost Ark
# 25 . The Fifth Element
# 26 . Harry Potter and the Prisoner of Azkaban
# 27 . Memento
# 28 . Harry Potter and the Order of the Phoenix
# 29 . Men in Black
# 30 . Inside Man

# %% [markdown]
# **Top 10 Movie Recommendation System**

# %%
Movie_Name = input('Enter Your Favourite Movie Name: ')

list_of_all_titles = df['Movie_Title'].tolist()

Find_Close_Match = difflib.get_close_matches(Movie_Name, list_of_all_titles)

Close_Match = Find_Close_Match[0]

Index_of_Movie = df[df.Movie_Title == Close_Match]['Movie_ID'].values[0]

Recommendation_Score = list(enumerate(Similarity_Score[Index_of_Movie]))

sorted_similar_movies = sorted(Recommendation_Score, key = lambda x:x[1], reverse = True)

print('Top 10 Movies Suggested For You : \n')

i = 1
for movie in Sorted_Similar_Movies:
  index = movie[0]
  title_from_index = df[df.Movie_ID==index]['Movie_Title'].values
  if (i<11):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Enter Your Favourite Movie Name: Men in Black
# Top 10 Movies Suggested For You :
#
# 1 . ['Batman']
# 2 . ['Star Trek II: The Wrath of Khan']
# 3 . ['The Devil Wears Prada']
# 4 . ['Cat on a Hot Tin Roof']
# 5 . ['Batman Forever']
# 6 . ['The English Patient']
# 7 . ['Catwoman']
# 8 . ['Pirates of the Caribbean: The Curse of the Black Pearl']
# 9 . ['Diamonds Are Forever']
# 10 . ['Pi']
